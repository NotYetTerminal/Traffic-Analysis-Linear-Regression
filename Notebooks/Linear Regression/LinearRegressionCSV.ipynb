# %%
# Notebook adapted from linear regression notebook from the Python Data Science Handbook
# Modified by: Gábor Major
# Last Modified date: 2024-10-01

# %%
# Imports
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
import numpy as np

# %%
# Simple Linear Regression

# %%
# Import test data from file
import pandas as pd
input_data = pd.read_csv('data_file.csv', sep=',', header=None)

# %%
# Convert to numpy data
print(input_data)
x = input_data[0].to_numpy()
y = input_data[1].to_numpy()
plt.scatter(x, y)
# Out:
#     0   1
# 0   5  10
# 1   6  12
# 2   8  14
# 3  10  16
# 4  11  18
# 5  13  21
# 6  15  22
# 7  17  24
# 8  19  25

# %%
# Fit line to data
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

# Use min and max to scale line to data
xfit = np.linspace(min(x) - 1, max(x) + 1, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);

# %%
# Print results
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     1.0944510035419126
# Model intercept: 5.353010625737898
